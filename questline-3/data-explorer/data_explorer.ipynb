# %% [markdown]
# # Data Explorer
#
# This notebook loads a sample sales dataset, inspects its structure, and summarizes the numerical fields.

# %%
import pandas as pd
from pathlib import Path

dataset_path = Path('../../questline-2/from-chaos-to-clarity/data-explorer/sample_dataset.csv')
df = pd.read_csv(dataset_path)

print('Dataset shape:', df.shape)
print('\nColumns:', list(df.columns))
print('\nData types:\n', df.dtypes)
print('\nMissing values:\n', df.isnull().sum())
print('\nNumerical summary:\n', df.describe(include='number').T)
